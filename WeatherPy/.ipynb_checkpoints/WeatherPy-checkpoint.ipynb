# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
#Initialize variables
cities_tried=[]      #Names of cities requested to API
cities_data=[]       #Store dictionaries with retrieved data from API
cities_found=[]      #Store names of cities from which data was retrieved correctly
cities_target=500    #Amount of cities wanted for analysis

# %%
#Keep requesting information until having the necessary datapoints (500 default)
while len(cities_found) < cities_target:
    
    #Random latitude and longitude values in ranges
    lat=random.randrange(-90,91)               
    lon=random.randrange(-180,181)              
    
    #Match lat and lon to find nearest city and country code using citipy
    city=citipy.nearest_city(lat, lon).city_name                   
    country=citipy.nearest_city(lat, lon).country_code
    
    #If city hasn't been requested 
    if city not in cities_tried:                
        
        #Add to the city requested list
        cities_tried.append(city)               
        
        #Retrieve json from API using city, country, api_key and specifying units as "metric"
        url=f"https://api.openweathermap.org/data/2.5/weather?q={city},{country}&appid={weather_api_key}&units=metric"
        data=requests.get(url).json()
        
        #Try to store the retreived data in a dictionary inside a list, if successful, append to cities_found.
        try:
            cities_data.append({"lon":data["coord"]["lon"],
                     "lat":data["coord"]["lat"],
                     "max_temp":data["main"]["temp_max"],
                     "humidity":data["main"]["humidity"],
                     "clouds":data["clouds"]["all"],
                     "wind":data["wind"]["speed"],
                     "country":data["sys"]["country"],
                     "date":data["dt"]
                    })
            cities_found.append(city)
            print(f'{city} found: {len(cities_found)} out of {cities_target}({round(len(cities_found)/cities_target*100)}%)')
        
        #If city isn't found in API, throw error message and don't account for city in cities_found.
        except KeyError:
            print(f'{city}:{data["message"]}')
# Out:
# pevek found, 1 out of 500
# godec:city not found
# inirida found, 2 out of 500
# taolanaro:city not found
# ushuaia found, 3 out of 500
# huangchuan found, 4 out of 500
# bluff found, 5 out of 500
# nizhneyansk:city not found
# thompson found, 6 out of 500
# albany found, 7 out of 500
# belushya guba:city not found
# tuy hoa found, 8 out of 500
# busselton found, 9 out of 500
# beloha found, 10 out of 500
# hermon found, 11 out of 500
# saldanha found, 12 out of 500
# castro found, 13 out of 500
# rikitea found, 14 out of 500
# punta arenas found, 15 out of 500
# chokurdakh found, 16 out of 500
# aras:city not found
# vaini found, 17 out of 500
# qaanaaq found, 18 out of 500
# rock sound found, 19 out of 500
# los llanos de aridane found, 20 out of 500
# sa kaeo found, 21 out of 500
# fairbanks found, 22 out of 500
# mahebourg found, 23 out of 500
# bengkulu found, 24 out of 500
# east london found, 25 out of 500
# atuona found, 26 out of 500
# nanortalik found, 27 out of 500
# hilo found, 28 out of 500
# kruisfontein found, 29 out of 500
# souillac found, 30 out of 500
# khatanga found, 31 out of 500
# seligenstadt found, 32 out of 500
# siedlce found, 33 out of 500
# puerto ayora found, 34 out of 500
# avarua found, 35 out of 500
# klaksvik found, 36 out of 500
# bang lamung found, 37 out of 500
# aquiraz found, 38 out of 500
# marsa matruh found, 39 out of 500
# amapa found, 40 out of 500
# coahuayana found, 41 out of 500
# hambantota found, 42 out of 500
# cayenne found, 43 out of 500
# zheleznodorozhnyy found, 44 out of 500
# illoqqortoormiut:city not found
# barrow found, 45 out of 500
# emba found, 46 out of 500
# kamenskoye:city not found
# portree found, 47 out of 500
# mount gambier found, 48 out of 500
# mataura:city not found
# diego de almagro found, 49 out of 500
# lebu found, 50 out of 500
# hermanus found, 51 out of 500
# asau:city not found
# marsh harbour found, 447 out of 500
# prince rupert found, 448 out of 500
# brandon found, 449 out of 500
# chitipa found, 450 out of 500
# novomykolayivka found, 451 out of 500
# hami found, 452 out of 500
# ancud found, 453 out of 500
# paluan found, 454 out of 500
# meyungs:city not found
# barra do garcas found, 455 out of 500
# muros found, 456 out of 500
# marawi found, 457 out of 500
# bodmin found, 458 out of 500
# zhangye found, 459 out of 500
# puerto colombia found, 460 out of 500
# notse found, 461 out of 500
# comodoro rivadavia found, 462 out of 500
# banjar found, 463 out of 500
# willowmore found, 464 out of 500
# tsaratanana found, 465 out of 500
# griffith found, 466 out of 500
# buala found, 467 out of 500
# katherine found, 468 out of 500
# samarai found, 469 out of 500
# reinosa found, 470 out of 500
# tawnat:city not found
# tripoli found, 471 out of 500
# bulgan found, 472 out of 500
# mys shmidta:city not found
# aitape found, 473 out of 500
# wattegama found, 474 out of 500
# marzuq:city not found
# milton found, 475 out of 500
# caraballeda found, 476 out of 500
# dwarka found, 477 out of 500
# karratha found, 478 out of 500
# pacific grove found, 479 out of 500
# parana found, 480 out of 500
# xinyu found, 481 out of 500
# ostrovnoy found, 482 out of 500
# vostok found, 483 out of 500
# hennenman found, 484 out of 500
# coffs harbour found, 485 out of 500
# mahibadhoo found, 486 out of 500
# wajima found, 487 out of 500
# manono found, 488 out of 500
# ust-maya found, 489 out of 500
# sokoni found, 490 out of 500
# nakskov found, 491 out of 500
# grajau found, 492 out of 500
# virden found, 493 out of 500
# constantine found, 494 out of 500
# iranshahr found, 495 out of 500
# lima found, 496 out of 500
# malanje found, 497 out of 500
# antofagasta found, 498 out of 500
# bardiyah found, 499 out of 500
# porto novo found, 500 out of 500

# %% [markdown]
# ---

# %%
# Convert the cities weather data into a Pandas DataFrame
cities_df=pd.DataFrame(cities_data,index=cities_found)
cities_df=countries_df.reset_index(drop=False)
cities_df=countries_df.rename(columns={"index":"city"})

# Show Record Count
cities_df.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21012\2974134145.py in <module>
#       1 # Convert the cities weather data into a Pandas DataFrame
# ----> 2 cities_df=pd.DataFrame(cities_data,index=cities_found)
#       3 cities_df=countries_df.reset_index(drop=False)
#       4 cities_df=countries_df.rename(columns={"index":"city"})
#       5
#
# NameError: name 'pd' is not defined

# %%
# Display sample data
cities_df.head()

# %%
# Export the City_Data into a csv
cities_df.to_csv("../output_data/cities.csv",index=False)

# %%
# Read saved data
cities_df=pd.read_csv("../output_data/cities.csv", na_values="", keep_default_na=False)
proper_names={
    "city":"City",
    "lon":"Longitude",
    "lat":"Latitude",
    "max_temp":"Maximum temperature (C°)",
    "humidity":"Humidity (%)",
    "clouds":"Cloudiness (%)",
    "wind":"Wind Speed (m/s)",
    "country":"Country",
    "date":"Date"
}

# %%
# Display sample data
cities_df.head()
# Out:
#          city       lon      lat  max_temp  humidity  clouds  wind country  \
# 0       pevek  170.3133  69.7008    -30.48        93     100  1.29      RU
# 1     inirida  -67.9239   3.8653     27.86        84      72  0.26      CO
# 2     ushuaia  -68.3000 -54.8000      9.04        69      93  2.36      AR
# 3  huangchuan  115.0394  32.1272      5.59        92     100  6.71      CN
# 4       bluff  168.3333 -46.6000     14.01        88      54  2.39      NZ
#
#          date
# 0  1676218705
# 1  1676218807
# 2  1676218472
# 3  1676218809
# 4  1676218681

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude

# %%
request_date="2023-02-13"

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
def plot_scatter(df,x_column,y_column):
    plt.figure(figsize=(8,6))
    plt.scatter(x=df[x_column],y=df[y_column], alpha=0.8, edgecolors="black")
    plt.grid(True)
    plt.xlabel(proper_names[x_column])
    plt.ylabel(proper_names[y_column])
    plt.title(f"City {proper_names[x_column]} vs {proper_names[y_column]} ({request_date})")
    plt.savefig(f"../output_data/{x_column}_vs{y_column}.png")
    plt.show()

# %%
# Build scatter plot for latitude vs. temperature
plot_scatter(cities_df,"lat","max_temp")

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plot_scatter(cities_df,"lat","humidity")

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plot_scatter(cities_df,"lat","clouds")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plot_scatter(cities_df,"lat","wind")

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def regress_plot(df,x_column,y_column,xcoord,ycoord):
    [slope, intersection, rvalue, pvalue, err]=linregress(df[x_column],df[y_column])
    plt.figure(figsize=(8,6))
    figure1=plt.scatter(x=df[x_column],y=df[y_column], alpha=0.8, edgecolors="black")
    plt.grid(True)
    plt.title(f"{proper_names[x_column]} vs {proper_names[y_column]} ({request_date})")
    plt.xlabel(proper_names[x_column])
    plt.ylabel(proper_names[y_column])
    y_values=slope*df[x_column]+intersection
    plt.plot(df[x_column],y_values, color="r")
    plt.annotate(f"{round(slope,3)}x + {round(intersection,3)}",xy=(xcoord,ycoord),color="r",fontsize=14)
    print(f"The r-value is: {round(rvalue**2,3)}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=cities_df[cities_df["lat"]>=0].copy()
# Display sample data
northern_hemi_df.head()
# Out:
#          city       lon      lat  max_temp  humidity  clouds  wind country  \
# 0       pevek  170.3133  69.7008    -30.48        93     100  1.29      RU
# 1     inirida  -67.9239   3.8653     27.86        84      72  0.26      CO
# 3  huangchuan  115.0394  32.1272      5.59        92     100  6.71      CN
# 5    thompson  -97.8558  55.7435    -12.91        85     100  0.00      CA
# 7     tuy hoa  109.3000  13.0833     23.09        93      99  1.83      VN
#
#          date
# 0  1676218705
# 1  1676218807
# 3  1676218809
# 5  1676218663
# 7  1676218810

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=cities_df[cities_df["lat"]<0].copy()
# Display sample data
southern_hemi_df.head()
# Out:
#         city       lon      lat  max_temp  humidity  clouds  wind country  \
# 2    ushuaia  -68.3000 -54.8000      9.04        69      93  2.36      AR
# 4      bluff  168.3333 -46.6000     14.01        88      54  2.39      NZ
# 6     albany  117.8917 -35.0169     15.26        77       0  4.32      AU
# 8  busselton  115.3333 -33.6500     17.30        67       0  5.97      AU
# 9     beloha   45.0500 -25.1667     26.28        73     100  5.59      MG
#
#          date
# 2  1676218472
# 4  1676218681
# 6  1676218578
# 8  1676218659
# 9  1676218669

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
regress_plot(northern_hemi_df,"lat","max_temp",0,0)
# Out:
# The r-value is: 0.761

# %%
# Linear regression on Southern Hemisphere
regress_plot(southern_hemi_df,"lat","max_temp",-50,30)
# Out:
# The r-value is: 0.191

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regress_plot(northern_hemi_df,"lat","humidity",50,20)
# Out:
# The r-value is: 0.235

# %%
# Southern Hemisphere
regress_plot(southern_hemi_df,"lat","humidity",-20,40)
# Out:
# The r-value is: 0.08

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regress_plot(northern_hemi_df,"lat","clouds",17,60)
# Out:
# The r-value is: 0.127

# %%
# Southern Hemisphere
regress_plot(southern_hemi_df,"lat","clouds",-40,80)
# Out:
# The r-value is: 0.093

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regress_plot(northern_hemi_df,"lat","wind",20,12.5)
# Out:
# The r-value is: 0.0

# %%
# Southern Hemisphere
regress_plot(southern_hemi_df,"lat","wind",-55,7)
# Out:
# The r-value is: 0.068

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
